# %% [markdown]
# # Data Science Visualization - Matplotlib

# %% [markdown]
# ## Tasks Today:
#
# 1) <b>Matplotlib</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Data Visulation <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Importing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Different Types of Charts <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Basics <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Customization <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Axis Labels & Line Marks <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Legend & Line Labels <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Subplots <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) <b>In-Class Exercise #1</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Presentation Worthiness <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) <b>In-Class Exercise #2</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Box Plot <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; j) Scatter Plot <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; k) Histograms <br>

# %% [markdown]
# ### Data Visualization <br>
# <p>Data visualization is one of the most powerful tools an analyst has for two main reasons. Firstly, it is unrivalled in it's ability to guide the analysts hand in determining 'what to look at next'. Often a visual is revealing of patterns in the data that are not easily discernable by just looking at dataframes. Secondly, they are an analysts greatest communication tool. Very often professional analysts need to present their results to groups of people responsible for taking action based on what the data says. Visuals can tell your story much better then raw numbers, so let's talk a little bit about how to make effective visuals that make a point.</p>

# %% [markdown]
# ##### Importing

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\bstan\anaconda3\envs\intro\lib\site-packages (3.4.2)
# Requirement already satisfied: numpy>=1.16 in c:\users\bstan\anaconda3\envs\intro\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\bstan\anaconda3\envs\intro\lib\site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bstan\anaconda3\envs\intro\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\bstan\anaconda3\envs\intro\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bstan\anaconda3\envs\intro\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\bstan\anaconda3\envs\intro\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: six>=1.5 in c:\users\bstan\anaconda3\envs\intro\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # standard

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\bstan\\anaconda3\\envs\\intro\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### Different Types of Charts <br>
# <ul>
#     <li><b>Line Chart:</b> Exploring data over time</li>
#     <li><b>Bar Chart:</b> Comparing categories of data and tracks changes over time</li>
#     <li><b>Pie Chart:</b> Explore parts of a whole, i.e. fractions</li>
#     <li><b>Scatter Plot:</b> Similar to line charts, track correlations between two categories</li>
#     <li><b>Histogram:</b> Unrelated from bar charts, show distribution of variables</li>
#     <li><b>Candlestick Chart:</b> Used a lot in financial sector, i.e. can compare a stock over a period of time</li>
#     <li><b>Box Chart:</b> Looks identical to candlestick charts, compares minimum, 1st, medium, 3rd quartiles, and max values</li>
# </ul>
#
# <p>Depending on what you need to accomplish in conceptualizing your data, you will go with a specific type of chart to portray your data.</p>

# %% [markdown]
# ### Basics <br>
# <p>Plots can be as detailed as you'd like them to be, but the simplest plot to start with can be done in just a few lines:</p>

# %%
plt.style.use('')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\envs\intro\lib\site-packages\matplotlib\style\core.py in use(style)
#     114             try:
# --> 115                 rc = rc_params_from_file(style, use_default_template=False)
#     116                 _apply_style(rc)
#
# ~\anaconda3\envs\intro\lib\site-packages\matplotlib\__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#     797     """
# --> 798     config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     799
#
# ~\anaconda3\envs\intro\lib\site-packages\matplotlib\__init__.py in _rc_params_in_file(fname, transform, fail_on_error)
#     726     rc_temp = {}
# --> 727     with _open_file_or_url(fname) as fd:
#     728         try:
#
# ~\anaconda3\envs\intro\lib\contextlib.py in __enter__(self)
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#
# ~\anaconda3\envs\intro\lib\site-packages\matplotlib\__init__.py in _open_file_or_url(fname)
#     704             encoding = "utf-8"
# --> 705         with open(fname, encoding=encoding) as f:
#     706             yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: ''
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-109-2f410764fcaa> in <module>
# ----> 1 plt.style.use('')
#
# ~\anaconda3\envs\intro\lib\site-packages\matplotlib\style\core.py in use(style)
#     116                 _apply_style(rc)
#     117             except IOError as err:
# --> 118                 raise IOError(
#     119                     "{!r} not found in the style library and input is not a "
#     120                     "valid URL or path; see `style.available` for list of "
#
# OSError: '' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %%
first_name, last_name = ('Brian', 'Stanton')
print(last_name)
# Out:
# Stanton

# %%
plt.subplots()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots()
ax.plot([13, 6, 4, 7, 5, 5, 2, 10])

# %%
plt.plot([13, 6, 4, 7, 5, 5, 2, 10])
plt.show()

# %% [markdown]
# ### Customization <br>
# <p>There's many customizable options when using Matplotlib, such as; line types, colors, labels, figure size, etc. We'll go over a few of them here:</p>

# %% [markdown]
# ##### Axis Labels & Line Marks

# %%
plt.plot([1, 2, 3, 4, 5], [22, 26, 39, 42, 67], 'c+--')
plt.plot([3, 4, 5, 6, 7], [10, 37, 33, 52, 83], 'ys:')
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ##### Legend & Line Labels

# %%
plt.plot([1600, 1700, 1800, 1900, 2000], [1.4, 1.5, 1.4, 1.6, 1.2], 'gx-', label='First Demographic')
plt.plot([1600, 1700, 1800, 1900, 2000], [0.9, 1.1, 1.2, 1.9, 1.8], 'ro-', label='Second Demographic')
plt.xlabel('Year')
plt.ylabel('Population (Billions)')
plt.legend()
plt.show()

# %% [markdown]
# ### Subplots <br>
# <p>Using the subplots method, you're able to create multiple plots within a single cell.</p>

# %%
# first plot
plot_1 = plt.subplot(2, 1, 1) # 2 rows, 1 column, show on 1st panel position
plot_1.plot([1600, 1700, 1800, 1900, 2000], [1.4, 1.5, 1.4, 1.6, 1.2], 'gx-', label='First Demographic')
plt.xlabel('Year')
plt.ylabel('Population (Billions)')
plot_1.set_xlim([1550, 2050])
plot_1.set_ylim([1,2])
plt.legend()

# second plot
plot_2 = plt.subplot(2, 1, 2) # 2 rows, 1 column, show on 2nd panel position
plot_2.plot([1600, 1700, 1800, 1900, 2000], [0.9, 1.1, 1.2, 1.9, 1.8], 'ro-', label='Second Demographic')
plt.xlabel('Year')
plt.ylabel('Population (Billions)')
plot_2.set_xlim([1550, 2050])
plt.legend()

plt.show()

# %% [markdown]
# ### In-Class Exercise #1 - Create a Graph that Depicts y = f(x)

# %%
import numpy as np

# use matplotlib to plot f(x)
y = np.linspace(0,100, num=20)

plt.plot(y)
plt.xlabel('X values')
plt.ylabel('Y Values')
plt.show()

# %% [markdown]
# ### Presentation Worthiness
# <p>Before we go into how to use this as a tool for data exploration, let's talk quickly about presentation-worthiness. In the next cell we're going to introduce customization of lines, colors, ticks, titles, fonts, and grids.</p>

# %%
fig, ax = plt.subplots(figsize = (20, 10))
# plt.figure(figsize=(20,10))
x = np.linspace(1,20, num=20)
y = x*2
plt.plot(x, y, 
         lw = 5, #line width
         ls = '--', # Line Style
         color = 'r', # Line color
         marker = '*', # Marker color
         markersize = 15, 
         markerfacecolor = 'b',
         label = 'Data'
        )
 
plt.title('Visual of F(x) Equation', fontsize=40, fontname='Times New Roman')
plt.xlabel('X Value', fontsize=32, fontname='Times New Roman')
plt.ylabel('Y Value', fontsize=32, fontname='Times New Roman')
plt.legend(loc='best', fontsize=32)
plt.grid(True)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
plt.xlim([0,20])
plt.ylim([0, 40])
plt.xticks([i for i in range(0, 21, 2)])
plt.yticks([i for i in range(0, 41,5)])
plt.show()

# %% [markdown]
# <p>It's sometimes nice to obsess a little bit over how your plots look. It's good practice paying attention to detail and it has huge payoff when you end up presenting your findings to other analysts and business parteners. Here's a more complex example of using the matplotlib api:</p>

# %%
markers = ['o', 'v', '^', '*', 's']
styles = ['-', '--', '-.', ':', '-']
colors = ['#588C7E', '#F2E394', '#F2AE72', '#D96459', '#8C4646']

# %%
x = np.linspace(1, 10, 50)

fig, ax = plt.subplots(figsize=(20,10))

# loop in range of 5 to create separate lines in our graph
for i in range(5):
    plt.plot(x, x**i, 
             lw = 5, #line width
             ls = styles[i], # Line Style
             color = colors[i], # Line color
             marker = markers[i], # Marker color
             markersize = 15, 
             markerfacecolor = colors[i],
             label = f'y=f(x^{i})'
    )

plt.title('Visualization of Exponential Growth', fontsize=40, fontname='Times New Roman')
plt.xlim(0,10)
plt.ylim(0,100)
plt.grid(True)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
plt.legend(loc=0, fontsize=28)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-ebe78cf8c8d3> in <module>
#       8              lw = 5, #line width
#       9              ls = styles[i], # Line Style
# ---> 10              color = colors[i], # Line color
#      11              marker = markers[i], # Marker color
#      12              markersize = 15,
#
# KeyError: 0

# %% [markdown]
# ### In-Class Exercise #2 - Customize the f(x) Plot Created Earlier <br>
# <p>Customize it however you would like...</p>

# %%
# students to do...

# %% [markdown]
# ### Scatter Plot

# %%
import csv
from  itertools import groupby

def read_csv(filename):
    with open(filename, 'r') as f:
        data = list(csv.reader(f))
    return data

# %%
flowers = read_csv('iris.csv')

# print(flowers)

colors = {
    'Iris-setosa': '#2B5B84', # Dark Blue/Purplish
    'Iris-versicolor': 'g',
    'Iris-virginica': 'purple'
}

fig, ax = plt.subplots(figsize=(15, 10))

for species, group in groupby(flowers, lambda x: x[4]):
    flower_data = list(group)
    sepal_length = [float(flower[0]) for flower in flower_data]
    sepal_width = [float(flower[1]) for flower in flower_data]
    plt.scatter(sepal_length, sepal_width, s=10, c=colors[species], label=species)

plt.title('Iris Dataset Sepal Length vs Sepal Width', fontsize=24)
plt.ylabel('Sepal Width (cm)', fontsize=14)
plt.xlabel('Sepal Length (cm)', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.show()

# %% [markdown]
# ### Box Plot

# %%
fig, ax = plt.subplots(figsize=(15, 10))

petal_length_list = []
for species, group in groupby(flowers, lambda x: x[4]):
    petal_length = [float(flower[2]) for flower in group]
    petal_length_list.append(petal_length)
    
plt.boxplot(petal_length_list)
plt.axis([0,4,0,10]) # xmin, xmax, ymin, ymax
plt.xticks([1, 2, 3], ['Setosa', 'Versicolor', 'Virginica'])
plt.title('Box Plot with Iris Dataset', fontsize=24)
plt.xlabel('Flower Variety', fontsize=16)
plt.ylabel('Petal Length (cm)', fontsize=16)

# Save thie figure as a png to local folder
fig.savefig('iris_petal_length_boxplot.png')

plt.show()

# %% [markdown]
# ### Histograms <br>
# <p>While line plots are great for visualizing trends in time series data, histograms are the king of visualizing distributions. Often, the distribution of a variable is what you're interested in, and a visualization provides a lot more information than a group of summary statistics.</p>

# %%
fig, ax = plt.subplots(figsize=(16, 9)) #Subplots makes a call in the background to create a plot area

# generate random data
data = np.random.uniform(0,10, 100)

# Plot data on a histogram
plt.hist(data, bins=50, color='b', label='Data', alpha=0.75)

plt.legend(loc='best')
plt.show()

# %% [markdown]
# <p>Let's take a look at a mystery/randomly generated DataFrame, and plot the results</p>

# %%
import pandas as pd
import numpy as np

def make_mystery_dataframe():
    customer_id = np.random.randint(1000,1200,10000)
    states = {1: 'California', 0: 'Colorado'}
    statelist = []
    agelist = []
    for i in range(10000):
        ind = np.random.randint(0,2)
        if ind == 0:
            statelist.append(states[ind])
            agelist.append(round(np.random.normal(loc = 30, scale = 3)))
        elif ind == 1:
            statelist.append(states[ind])
            agelist.append(round(np.random.normal(loc = 40, scale = 5)))
    mystery_df = pd.DataFrame.from_dict({
        'customer_id': customer_id,
        'ages':agelist,
        'state': statelist
    })
    
    return mystery_df


df = make_mystery_dataframe()

df.head()
# Out:
#    customer_id  ages       state
# 0         1175    30    Colorado
# 1         1042    43  California
# 2         1153    39  California
# 3         1048    30    Colorado
# 4         1127    35  California

# %%
with plt.style.context('dark_background'):
    # plt.style.use('fivethirtyeight')
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

    # First Subplot - California Histogram
    ax1.hist(df[df['state'] == 'California']['ages'], label='Ages in California', bins=40, range=(20,60))
    ax1.set_xlabel('Age', fontname='Times New Roman', fontsize = 35)
    ax1.set_ylabel('Frequency', fontname='Times New Roman', fontsize = 35)
    ax1.legend(loc=0, fontsize=16)
    ax1.tick_params(axis='both', labelsize=18)


    # Second Subplot - Colorado Histogram
    ax2.hist(df[df['state'] == 'Colorado']['ages'], label='Ages in Colorado', color='r', bins=40, range=(20,60))
    ax2.set_xlabel('Age', fontname='Times New Roman', fontsize = 35)
    ax2.set_ylabel('Frequency', fontname='Times New Roman', fontsize = 35)
    ax2.legend(loc=0, fontsize=16)
    ax2.tick_params(axis='both', labelsize=18)

    plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')
